# %% [markdown]
# <a href="https://colab.research.google.com/github/suhailnoor18/Data_science_life_cycle_cw2/blob/main/DSPL_CW2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#reading the csv file
df = pd.read_csv('/content/Classified_Hotels_Sri_Lanka.csv')

df.head()
# Out:
#                         Name  \
# 0       CINNAMON GRAND HOTEL
# 1  CINNAMON LAKESIDE COLOMBO
# 2             CINNAMON LODGE
# 3             GALADARI HOTEL
# 4       EDEN RESORTS AND SPA
#
#                                              Address  Rooms  Grade  \
# 0                     NO. 77, GALLE ROAD, COLOMBO 03    501   FIVE
# 1  115, SRI CHITAMPALAM A GARDINER MAWATHA, COLOM...    352   FIVE
# 2                              P.O. BOX 02, HABARANE    162   FIVE
# 3                     NO. 64, LOTUS ROAD, COLOMBO 01    408  THREE
# 4                             KALUWAMODARA, BERUWALA    158   FIVE
#
#        District               AGA Division                         PS/MC/UC  \
# 0       Colombo                    Colombo   Colombo Divisional Secretariat
# 1       Colombo                    Colombo   Colombo Divisional Secretariat
# 2  Anuradhapura               Anuradhapura                Anuradhapura East
# ...

# %%
df['Grade'].unique()
# Out:
# array(['FIVE', 'THREE', 'FOUR', 'TWO', 'ONE'], dtype=object)

# %%
# Assuming your grade column is named 'Grade'
grade_mapping = {
    'ONE': 1,
    'TWO': 2,
    'THREE': 3,
    'FOUR': 4,
    'FIVE': 5
}

# Before applying the mapping, ensure the 'Grade' column is in the correct format:
df['Grade'] = df['Grade'].str.upper()  # Convert to uppercase to match the keys in grade_mapping

# Now apply the mapping:
df['Grade'] = df['Grade'].map(grade_mapping)

df.head()
# Out:
#                         Name  \
# 0       CINNAMON GRAND HOTEL
# 1  CINNAMON LAKESIDE COLOMBO
# 2             CINNAMON LODGE
# 3             GALADARI HOTEL
# 4       EDEN RESORTS AND SPA
#
#                                              Address  Rooms  Grade  \
# 0                     NO. 77, GALLE ROAD, COLOMBO 03    501      5
# 1  115, SRI CHITAMPALAM A GARDINER MAWATHA, COLOM...    352      5
# 2                              P.O. BOX 02, HABARANE    162      5
# 3                     NO. 64, LOTUS ROAD, COLOMBO 01    408      3
# 4                             KALUWAMODARA, BERUWALA    158      5
#
#        District               AGA Division                         PS/MC/UC  \
# 0       Colombo                    Colombo   Colombo Divisional Secretariat
# 1       Colombo                    Colombo   Colombo Divisional Secretariat
# 2  Anuradhapura               Anuradhapura                Anuradhapura East
# ...

# %%
df['Grade'].unique()
# Out:
# array([5, 3, 4, 2, 1])

# %%
#missing values in the df dataframe
missingvalues = df.isnull().sum()
missingvalues
# Out:
# Name            0
# Address         0
# Rooms           0
# Grade           0
# District        0
# AGA Division    0
# PS/MC/UC        0
# Logitiute       0
# Latitude        0
# dtype: int64

# %%
# Identify all duplicate rows in traincsv dataset
duplicate_rows = df[df.duplicated(keep=False)]
print(f"Total Duplicates: {len(duplicate_rows)}")
# Out:
# Total Duplicates: 0

# %% [markdown]
# Feature Engineering

# %%
#categorizing from district to region
district_to_region = {
    "Colombo": "Western",
    "Gampaha": "Western",
    "Kalutara": "Western",
    "Kandy": "Central",
    "Matale": "Central",
    "Nuwara Eliya": "Central",
    "Galle": "Southern",
    "Matara": "Southern",
    "Hambantota": "Southern",
    "Jaffna": "Northern",
    "Kilinochchi": "Northern",
    "Mannar": "Northern",
    "Vavuniya": "Northern",
    "Mullaitivu": "Northern",
    "Batticaloa": "Eastern",
    "Ampara": "Eastern",
    "Trincomalee": "Eastern",
    "Kurunegala": "North Western",
    "Puttalam": "North Western",
    "Anuradhapura": "North Central",
    "Polonnaruwa": "North Central",
    "Badulla": "Uva",
    "Monaragala": "Uva",
    "Ratnapura": "Sabaragamuwa",
    "Kegalle": "Sabaragamuwa"
}

# Map District to Region
df["Region"] = df["District"].map(district_to_region)

# %%
df.head()
# Out:
#                         Name  \
# 0       CINNAMON GRAND HOTEL
# 1  CINNAMON LAKESIDE COLOMBO
# 2             CINNAMON LODGE
# 3             GALADARI HOTEL
# 4       EDEN RESORTS AND SPA
#
#                                              Address  Rooms  Grade  \
# 0                     NO. 77, GALLE ROAD, COLOMBO 03    501      5
# 1  115, SRI CHITAMPALAM A GARDINER MAWATHA, COLOM...    352      5
# 2                              P.O. BOX 02, HABARANE    162      5
# 3                     NO. 64, LOTUS ROAD, COLOMBO 01    408      3
# 4                             KALUWAMODARA, BERUWALA    158      5
#
#        District               AGA Division                         PS/MC/UC  \
# 0       Colombo                    Colombo   Colombo Divisional Secretariat
# 1       Colombo                    Colombo   Colombo Divisional Secretariat
# 2  Anuradhapura               Anuradhapura                Anuradhapura East
# ...

# %%
#hotel size distribution
def classify_hotel_size(rooms):
    if rooms < 100:
        return "Small"
    elif 100 <= rooms <= 300:
        return "Medium"
    else:
        return "Large"

df["Hotel_Size_Category"] = df["Rooms"].apply(classify_hotel_size)

# -----------------------
# Display sample of updated DataFrame
# -----------------------
df[["Name", "District", "Region", "Rooms", "Hotel_Size_Category"]].head()
# Out:
#                         Name      District         Region  Rooms  \
# 0       CINNAMON GRAND HOTEL       Colombo        Western    501
# 1  CINNAMON LAKESIDE COLOMBO       Colombo        Western    352
# 2             CINNAMON LODGE  Anuradhapura  North Central    162
# 3             GALADARI HOTEL       Colombo        Western    408
# 4       EDEN RESORTS AND SPA      Kalutara        Western    158
#
#   Hotel_Size_Category
# 0               Large
# 1               Large
# 2              Medium
# 3               Large
# 4              Medium

# %%
df.head()
# Out:
#                         Name  \
# 0       CINNAMON GRAND HOTEL
# 1  CINNAMON LAKESIDE COLOMBO
# 2             CINNAMON LODGE
# 3             GALADARI HOTEL
# 4       EDEN RESORTS AND SPA
#
#                                              Address  Rooms  Grade  \
# 0                     NO. 77, GALLE ROAD, COLOMBO 03    501      5
# 1  115, SRI CHITAMPALAM A GARDINER MAWATHA, COLOM...    352      5
# 2                              P.O. BOX 02, HABARANE    162      5
# 3                     NO. 64, LOTUS ROAD, COLOMBO 01    408      3
# 4                             KALUWAMODARA, BERUWALA    158      5
#
#        District               AGA Division                         PS/MC/UC  \
# 0       Colombo                    Colombo   Colombo Divisional Secretariat
# 1       Colombo                    Colombo   Colombo Divisional Secretariat
# 2  Anuradhapura               Anuradhapura                Anuradhapura East
# ...

# %%
# Save the cleaned DataFrame to a CSV file
df.to_csv('cleaned_hotels_data.csv', index=False)
